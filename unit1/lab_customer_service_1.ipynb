# %% [markdown]
# # LAB1

# %%
# Summary:
#1.prepare the env. import libraries needed (Check notebook file name 'library')
#2. we export the needed files as dataframes using Pandas
#!! through this task we figured out: it is way easier to first organize ur dataset before concatenating or merging them
#3. let's explore the data using .head(), .shape, info
#4. lets clean the data a bit. rename, map, str.lower
#5. let's concatenate the 3 files into a new dataframe
#6. let's get familiar in using dtype and select 
#7. getting familiar with NA values, dropping, checking etc.

# %%
import numpy as np
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
#shape shows us the number of rows and columns as a tuple
file1.shape

# %%
file2.shape

# %%
file3.shape

# %%
file1.info()

# %%
df1=pd.DataFrame(file1)
df2=pd.DataFrame(file2)
df3=pd.DataFrame(file3)

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
#i just want to compare the columns in my datasets- what columns we have in common, what columns are different
df1.columns.intersection(df2.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df1.columns.intersection(df3.columns)
# Out:
# Index(['Customer', 'Education', 'Customer Lifetime Value', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df1.columns.difference(df2.columns)
# Out:
# Index([], dtype='object')

# %%
df1.columns.difference(df3.columns)
# Out:
# Index(['GENDER', 'ST'], dtype='object')

# %%
# oh let's have all columns in the same order. We chose df3.columns because its the neatest amongst the datasets
column_names=df3.columns

# %%
#using reindex to change columns order 
df1=df1.reindex(columns=column_names)

# %%
df2=df2.reindex(columns=column_names)

# %%
df1.head()
# Out:
#   Customer  State Customer Lifetime Value             Education  Gender  \
# 0  RB50392    NaN                     NaN                Master     NaN
# 1  QZ44356    NaN              697953.59%              Bachelor     NaN
# 2  AI49188    NaN             1288743.17%              Bachelor     NaN
# 3  WW63253    NaN              764586.18%              Bachelor     NaN
# 4  GA49547    NaN              536307.65%  High School or Below     NaN
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Total Claim Amount  Vehicle Class
# 0            2.704934  Four-Door Car
# ...

# %%
df2.head()
# Out:
#   Customer  State Customer Lifetime Value Education  Gender  Income  \
# 0  GS98873    NaN              323912.47%  Bachelor     NaN   16061
# 1  CW49887    NaN              462680.11%    Master     NaN   79487
# 2  MY31220    NaN              899704.02%   College     NaN   54230
# 3  UH35128    NaN             2580706.30%   College     NaN   71210
# 4  WH52799    NaN              380812.21%   College     NaN   94903
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    Total Claim Amount  Vehicle Class
# 0               633.6  Four-Door Car
# 1               547.2            SUV
# 2               537.6   Two-Door Car
# ...

# %%
df3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
# after having everything in order. we can concatenate our DataFrames
data=pd.concat ([df1,df2,df3])

# %%
data.shape
# Out:
# (12074, 11)

# %%
data.head()
# Out:
#   Customer State Customer Lifetime Value             Education Gender  \
# 0  RB50392   NaN                     NaN                Master    NaN
# 1  QZ44356   NaN              697953.59%              Bachelor    NaN
# 2  AI49188   NaN             1288743.17%              Bachelor    NaN
# 3  WW63253   NaN              764586.18%              Bachelor    NaN
# 4  GA49547   NaN              536307.65%  High School or Below    NaN
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Total Claim Amount  Vehicle Class
# 0            2.704934  Four-Door Car
# ...

# %%
#lets clean the column titles, use rename str.lower
data.columns=data.columns.str.lower()

# %%
new_data=data.rename(columns={'number of open complaints': 'no. of open complaints'})
new_data.head ()
# Out:
#   customer state customer lifetime value             education gender  \
# 0  RB50392   NaN                     NaN                Master    NaN
# 1  QZ44356   NaN              697953.59%              Bachelor    NaN
# 2  AI49188   NaN             1288743.17%              Bachelor    NaN
# 3  WW63253   NaN              764586.18%              Bachelor    NaN
# 4  GA49547   NaN              536307.65%  High School or Below    NaN
#
#     income  monthly premium auto no. of open complaints     policy type  \
# 0      0.0                1000.0                 1/0/00   Personal Auto
# 1      0.0                  94.0                 1/0/00   Personal Auto
# 2  48767.0                 108.0                 1/0/00   Personal Auto
# 3      0.0                 106.0                 1/0/00  Corporate Auto
# 4  36357.0                  68.0                 1/0/00   Personal Auto
#
#    total claim amount  vehicle class
# 0            2.704934  Four-Door Car
# ...

# %%
new_data= new_data.drop(['no. of open complaints', 'education'],axis=1)# axis 1 for columns
new_data= new_data.drop(['vehicle class'],axis=1)# axis 1 for columns

# %%
new_data.head()
# Out:
#   customer state customer lifetime value gender   income  \
# 0  RB50392   NaN                     NaN    NaN      0.0
# 1  QZ44356   NaN              697953.59%    NaN      0.0
# 2  AI49188   NaN             1288743.17%    NaN  48767.0
# 3  WW63253   NaN              764586.18%    NaN      0.0
# 4  GA49547   NaN              536307.65%    NaN  36357.0
#
#    monthly premium auto     policy type  total claim amount
# 0                1000.0   Personal Auto            2.704934
# 1                  94.0   Personal Auto         1131.464935
# 2                 108.0   Personal Auto          566.472247
# 3                 106.0  Corporate Auto          529.881344
# 4                  68.0   Personal Auto           17.269323

# %%
new_data.shape
# Out:
# (12074, 8)

# %%
#how do i know the type of the data? use dtypeS
new_data.dtypes
# Out:
# customer                    object
# state                       object
# customer lifetime value     object
# gender                      object
# income                     float64
# monthly premium auto       float64
# policy type                 object
# total claim amount         float64
# dtype: object

# %%
new_data.select_dtypes(include=['float64'])
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# 5     62902.0                  69.0          159.383042
# 6     55350.0                  67.0          321.600000
# 7         0.0                 101.0          363.029680
# 8     14072.0                  71.0          511.200000
# 9     28812.0                  93.0          425.527834
# 10        0.0                  67.0          482.400000
# 11        0.0                 110.0          528.000000
# 12    77026.0                 110.0          472.029737
# 13    99845.0                 110.0          528.000000
# 14    83689.0                  70.0          307.139132
# 15    24599.0                  64.0           42.920271
# ...

# %%
new_data.select_dtypes(include=['object'])
# Out:
#      customer       state customer lifetime value gender     policy type
# 0     RB50392         NaN                     NaN    NaN   Personal Auto
# 1     QZ44356         NaN              697953.59%    NaN   Personal Auto
# 2     AI49188         NaN             1288743.17%    NaN   Personal Auto
# 3     WW63253         NaN              764586.18%    NaN  Corporate Auto
# 4     GA49547         NaN              536307.65%    NaN   Personal Auto
# 5     OC83172         NaN              825629.78%    NaN   Personal Auto
# 6     XZ87318         NaN              538089.86%    NaN  Corporate Auto
# 7     CF85061         NaN              721610.03%    NaN  Corporate Auto
# 8     DY87989         NaN             2412750.40%    NaN  Corporate Auto
# 9     BQ94931         NaN              738817.81%    NaN    Special Auto
# 10    SX51350         NaN              473899.20%    NaN   Personal Auto
# 11    VQ65197         NaN              819719.71%    NaN   Personal Auto
# ...

# %%
# we multiply by 100 to get rid of %
new_data['customer lifetime value'] = 100 * new_data['customer lifetime value']

# %%
new_data.dtypes
# Out:
# customer                    object
# state                       object
# customer lifetime value     object
# gender                      object
# income                     float64
# monthly premium auto       float64
# policy type                 object
# total claim amount         float64
# dtype: object

# %%
# changing the type by using pd.to_numeri
new_data ['customer lifetime value']= pd.to_numeric (new_data ['customer lifetime value'], errors = 'coerce')
new_data.dtypes
# Out:
# customer                    object
# state                       object
# customer lifetime value    float64
# gender                      object
# income                     float64
# monthly premium auto       float64
# policy type                 object
# total claim amount         float64
# dtype: object

# %%
# Nans are basically missing values. sometimes we don't need to replace them or delete so our analysis cann't be affected

# %%
#map function is used to substitute a value in a series with another value. example below

# %%
# how to find duplicates:
#we can find duplicates based on specific column using duplicat_new_data = new_data[new_data.duplicated(['Customer'])]
duplicate_new_data = new_data[new_data.duplicated()]

# %%
# removing duplicates
new_data = new_data.drop_duplicates()

# %%
new_data.shape
# Out:
# (2294, 8)

# %%
new_data=new_data[new_data['income']<=0]

# %%
new_data.shape
# Out:
# (2294, 8)

# %%
new_data.head()
# Out:
#    customer state  customer lifetime value gender  income  \
# 0   RB50392   NaN                      NaN    NaN     0.0
# 1   QZ44356   NaN                      NaN    NaN     0.0
# 3   WW63253   NaN                      NaN    NaN     0.0
# 7   CF85061   NaN                      NaN    NaN     0.0
# 10  SX51350   NaN                      NaN    NaN     0.0
#
#     monthly premium auto     policy type  total claim amount
# 0                 1000.0   Personal Auto            2.704934
# 1                   94.0   Personal Auto         1131.464935
# 3                  106.0  Corporate Auto          529.881344
# 7                  101.0  Corporate Auto          363.029680
# 10                  67.0   Personal Auto          482.400000

# %%
#since the dataset is not mine, i will also drop NaN
new_data.dropna()
# Out:
#      customer       state  customer lifetime value gender  income  \
# 0     SA25987  Washington             3.479138e+05      M     0.0
# 1     TB86706     Arizona             2.502637e+05      M     0.0
# 3     KX23516  California             4.455843e+05      F     0.0
# 6     FP59138      Oregon             1.302413e+06      M     0.0
# 12    VG31922      Nevada             6.516215e+05      F     0.0
# 14    AL78075      Oregon             3.810238e+05      M     0.0
# 15    WA97671     Arizona             6.334466e+05      M     0.0
# 18    ID45268  California             6.006963e+05      F     0.0
# 23    CS55808  California             9.392558e+05      M     0.0
# 25    IV55977      Oregon             2.693759e+05      M     0.0
# 27    LZ89773  California             2.326865e+05      M     0.0
# 34    JT41591  Washington             2.705988e+05      M     0.0
# 36    KI64666      Nevada             2.244528e+06      F     0.0
# ...

# %%
new_data.shape
# Out:
# (2294, 8)

# %%
#what else can we do:
#DataFrame.isna : Indicate missing values. entries that are NA

#DataFrame.notna: Indicate existing (non-missing) values. basically entries that are notNA.

#DataFrame.fillna: Replace missing values.

#Series.dropna: Drop missing values.
# Index.dropna: Drop missing indices

# %%
new_data.notna() #true = data are NA, False= we have values
# Out:
#       customer  state  customer lifetime value  gender  income  \
# 0         True  False                    False   False    True
# 1         True  False                    False   False    True
# 3         True  False                    False   False    True
# 7         True  False                    False   False    True
# 10        True  False                    False   False    True
# 11        True  False                    False   False    True
# 23        True  False                    False   False    True
# 26        True  False                    False   False    True
# 32        True  False                    False   False    True
# 33        True  False                    False   False    True
# 38        True  False                    False   False    True
# 40        True  False                    False   False    True
# 46        True  False                    False   False    True
# 48        True  False                    False   False    True
# ...
